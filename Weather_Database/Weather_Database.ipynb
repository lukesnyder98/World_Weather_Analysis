# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the time library and datetime module.
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | libertador general san martin
# City not found. Skipping...
# Processing Record 2 of Set 1 | castro
# City not found. Skipping...
# Processing Record 3 of Set 1 | morrelganj
# City not found. Skipping...
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | roma
# Processing Record 7 of Set 1 | karratha
# Processing Record 8 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | rexburg
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 1 | tarhunah
# City not found. Skipping...
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | nantucket
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | queimadas
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | san policarpo
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | portland
# Processing Record 25 of Set 1 | andenes
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | aswan
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | manicaragua
# Processing Record 34 of Set 1 | zelenoborskiy
# Processing Record 35 of Set 1 | katakwi
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | nanortalik
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | vestmanna
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | lengshuijiang
# Processing Record 45 of Set 1 | tessalit
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | sarahan
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | kuusamo
# Processing Record 1 of Set 2 | huaral
# Processing Record 2 of Set 2 | vardo
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | coquimbo
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | rafaela
# Processing Record 7 of Set 2 | sambava
# Processing Record 8 of Set 2 | northam
# Processing Record 9 of Set 2 | nelson bay
# Processing Record 10 of Set 2 | mogadishu
# Processing Record 11 of Set 2 | nizhnevartovsk
# Processing Record 12 of Set 2 | saldanha
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 2 | high prairie
# Processing Record 17 of Set 2 | pangnirtung
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | corn island
# Processing Record 21 of Set 2 | neunkirchen
# Processing Record 22 of Set 2 | giarmata
# Processing Record 23 of Set 2 | ganj muradabad
# Processing Record 24 of Set 2 | merauke
# Processing Record 25 of Set 2 | taoudenni
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | kaura namoda
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | roebourne
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | lahad datu
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 2 | shubarshi
# Processing Record 39 of Set 2 | tiarei
# Processing Record 40 of Set 2 | oranjemund
# Processing Record 41 of Set 2 | geraldton
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | port blair
# Processing Record 44 of Set 2 | kaeo
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | kropotkin
# Processing Record 47 of Set 2 | cabo rojo
# Processing Record 48 of Set 2 | olafsvik
# Processing Record 49 of Set 2 | vrangel
# Processing Record 50 of Set 2 | bara
# Processing Record 1 of Set 3 | lasa
# Processing Record 2 of Set 3 | rocha
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | baneh
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | henderson
# Processing Record 10 of Set 3 | carayao
# Processing Record 11 of Set 3 | nova odesa
# Processing Record 12 of Set 3 | neyshabur
# Processing Record 13 of Set 3 | rio grande
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | ibra
# Processing Record 16 of Set 3 | tsiroanomandidy
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | novyy urengoy
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | puerto baquerizo moreno
# Processing Record 22 of Set 3 | broken hill
# Processing Record 23 of Set 3 | ahipara
# Processing Record 24 of Set 3 | bang mun nak
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | albany
# Processing Record 27 of Set 3 | seymchan
# Processing Record 28 of Set 3 | faanui
# Processing Record 29 of Set 3 | goba
# Processing Record 30 of Set 3 | zhicheng
# Processing Record 31 of Set 3 | flin flon
# Processing Record 32 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 33 of Set 3 | muli
# Processing Record 34 of Set 3 | mao
# Processing Record 35 of Set 3 | santa maria
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | mysliborz
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 3 | constitucion
# Processing Record 42 of Set 3 | viet tri
# Processing Record 43 of Set 3 | monte santo de minas
# Processing Record 44 of Set 3 | novoagansk
# Processing Record 45 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 3 | dubrovytsya
# Processing Record 47 of Set 3 | bayir
# Processing Record 48 of Set 3 | turukhansk
# Processing Record 49 of Set 3 | hasaki
# Processing Record 50 of Set 3 | auki
# Processing Record 1 of Set 4 | buala
# Processing Record 2 of Set 4 | alihe
# Processing Record 3 of Set 4 | point pleasant
# Processing Record 4 of Set 4 | san juan
# Processing Record 5 of Set 4 | deder
# Processing Record 6 of Set 4 | udgir
# Processing Record 7 of Set 4 | kendari
# Processing Record 8 of Set 4 | azua
# Processing Record 9 of Set 4 | kargasok
# Processing Record 10 of Set 4 | abha
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | saint-pierre
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | guarabira
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 4 | skegness
# Processing Record 18 of Set 4 | the valley
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | bogovarovo
# Processing Record 21 of Set 4 | ternate
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | zalantun
# Processing Record 24 of Set 4 | manzhouli
# Processing Record 25 of Set 4 | juneau
# Processing Record 26 of Set 4 | mikuni
# Processing Record 27 of Set 4 | vostok
# Processing Record 28 of Set 4 | bonthe
# Processing Record 29 of Set 4 | muroto
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | jumla
# Processing Record 33 of Set 4 | vicksburg
# Processing Record 34 of Set 4 | sioux lookout
# Processing Record 35 of Set 4 | agirish
# Processing Record 36 of Set 4 | desaguadero
# Processing Record 37 of Set 4 | masterton
# Processing Record 38 of Set 4 | taft
# Processing Record 39 of Set 4 | san patricio
# Processing Record 40 of Set 4 | jiuquan
# Processing Record 41 of Set 4 | sao jose da coroa grande
# Processing Record 42 of Set 4 | nioro
# Processing Record 43 of Set 4 | uusikaupunki
# Processing Record 44 of Set 4 | la asuncion
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | bakel
# Processing Record 47 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 4 | acaponeta
# Processing Record 49 of Set 4 | cherskiy
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | emporia
# Processing Record 4 of Set 5 | stokmarknes
# Processing Record 5 of Set 5 | kurumkan
# Processing Record 6 of Set 5 | poso
# Processing Record 7 of Set 5 | jacqueville
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | todos santos
# Processing Record 10 of Set 5 | mahebourg
# Processing Record 11 of Set 5 | hermosillo
# Processing Record 12 of Set 5 | tezu
# Processing Record 13 of Set 5 | sistranda
# Processing Record 14 of Set 5 | homer
# Processing Record 15 of Set 5 | anchorage
# Processing Record 16 of Set 5 | kletskaya
# Processing Record 17 of Set 5 | puerto ayora
# Processing Record 18 of Set 5 | kadoma
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | vanavara
# Processing Record 21 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | at-bashi
# Processing Record 25 of Set 5 | ampanihy
# Processing Record 26 of Set 5 | ishinomaki
# Processing Record 27 of Set 5 | salinas
# Processing Record 28 of Set 5 | cabo san lucas
# Processing Record 29 of Set 5 | sinop
# Processing Record 30 of Set 5 | corner brook
# Processing Record 31 of Set 5 | mahibadhoo
# Processing Record 32 of Set 5 | namatanai
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | ust-nera
# Processing Record 35 of Set 5 | poum
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | brae
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | kaitangata
# Processing Record 40 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 5 | krasnoselkup
# Processing Record 42 of Set 5 | ancud
# Processing Record 43 of Set 5 | broome
# Processing Record 44 of Set 5 | kiruna
# Processing Record 45 of Set 5 | luderitz
# Processing Record 46 of Set 5 | margate
# Processing Record 47 of Set 5 | mar del plata
# Processing Record 48 of Set 5 | mahajanga
# Processing Record 49 of Set 5 | saint-joseph
# Processing Record 50 of Set 5 | bose
# Processing Record 1 of Set 6 | vieques
# Processing Record 2 of Set 6 | salinopolis
# Processing Record 3 of Set 6 | ozinki
# Processing Record 4 of Set 6 | grand-santi
# Processing Record 5 of Set 6 | fairbanks
# Processing Record 6 of Set 6 | tuatapere
# Processing Record 7 of Set 6 | abu samrah
# Processing Record 8 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | bay city
# Processing Record 11 of Set 6 | hammerfest
# Processing Record 12 of Set 6 | dolinsk
# Processing Record 13 of Set 6 | lebedinyy
# Processing Record 14 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 6 | bouna
# Processing Record 16 of Set 6 | acarau
# Processing Record 17 of Set 6 | airai
# Processing Record 18 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 19 of Set 6 | ko samui
# Processing Record 20 of Set 6 | atar
# Processing Record 21 of Set 6 | shellbrook
# Processing Record 22 of Set 6 | thung song
# Processing Record 23 of Set 6 | sibolga
# Processing Record 24 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 6 | longyearbyen
# Processing Record 26 of Set 6 | schramberg
# Processing Record 27 of Set 6 | isangel
# Processing Record 28 of Set 6 | pacific grove
# Processing Record 29 of Set 6 | kapit
# Processing Record 30 of Set 6 | redlands
# Processing Record 31 of Set 6 | concordia
# Processing Record 32 of Set 6 | okhotsk
# Processing Record 33 of Set 6 | yar-sale
# Processing Record 34 of Set 6 | acapulco
# Processing Record 35 of Set 6 | manacapuru
# Processing Record 36 of Set 6 | ponta delgada
# Processing Record 37 of Set 6 | mackenzie
# Processing Record 38 of Set 6 | ranong
# Processing Record 39 of Set 6 | laguna
# Processing Record 40 of Set 6 | tari
# Processing Record 41 of Set 6 | ponta do sol
# Processing Record 42 of Set 6 | katherine
# Processing Record 43 of Set 6 | derzhavinsk
# Processing Record 44 of Set 6 | sharan
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | gayeri
# Processing Record 47 of Set 6 | lavrentiya
# Processing Record 48 of Set 6 | khatanga
# Processing Record 49 of Set 6 | ribeira grande
# Processing Record 50 of Set 6 | alofi
# Processing Record 1 of Set 7 | gornopravdinsk
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | lazaro cardenas
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | zhezkazgan
# Processing Record 6 of Set 7 | cozumel
# Processing Record 7 of Set 7 | troitsko-pechorsk
# Processing Record 8 of Set 7 | biak
# Processing Record 9 of Set 7 | namuac
# Processing Record 10 of Set 7 | glinka
# Processing Record 11 of Set 7 | nchelenge
# Processing Record 12 of Set 7 | porto novo
# Processing Record 13 of Set 7 | yanam
# Processing Record 14 of Set 7 | vao
# Processing Record 15 of Set 7 | lancaster
# Processing Record 16 of Set 7 | campana
# Processing Record 17 of Set 7 | havelock
# Processing Record 18 of Set 7 | flinders
# Processing Record 19 of Set 7 | fortuna
# Processing Record 20 of Set 7 | guerrero negro
# Processing Record 21 of Set 7 | burica
# City not found. Skipping...
# Processing Record 22 of Set 7 | lakatoro
# Processing Record 23 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 7 | iroquois
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | faya
# Processing Record 28 of Set 7 | russell
# Processing Record 29 of Set 7 | khani
# Processing Record 30 of Set 7 | sampit
# Processing Record 31 of Set 7 | kupang
# Processing Record 32 of Set 7 | vagay
# Processing Record 33 of Set 7 | lakes entrance
# Processing Record 34 of Set 7 | taguatinga
# Processing Record 35 of Set 7 | ye
# City not found. Skipping...
# Processing Record 36 of Set 7 | natal
# Processing Record 37 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 7 | tomatlan
# Processing Record 39 of Set 7 | port lincoln
# Processing Record 40 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | macae
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 7 | bacolod
# Processing Record 45 of Set 7 | batemans bay
# Processing Record 46 of Set 7 | nova olinda do norte
# Processing Record 47 of Set 7 | sangar
# Processing Record 48 of Set 7 | inirida
# Processing Record 49 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 7 | acajutla
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | qaqortoq
# Processing Record 3 of Set 8 | tutoia
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | berlevag
# Processing Record 6 of Set 8 | katsuura
# Processing Record 7 of Set 8 | mitsamiouli
# Processing Record 8 of Set 8 | san pedro
# Processing Record 9 of Set 8 | adrar
# Processing Record 10 of Set 8 | oktyabrskoye
# Processing Record 11 of Set 8 | torbay
# Processing Record 12 of Set 8 | kasulu
# Processing Record 13 of Set 8 | viedma
# Processing Record 14 of Set 8 | marystown
# Processing Record 15 of Set 8 | irbil
# Processing Record 16 of Set 8 | whitecourt
# Processing Record 17 of Set 8 | tifton
# Processing Record 18 of Set 8 | saint-francois
# Processing Record 19 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 8 | rajnagar
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | mbandaka
# Processing Record 23 of Set 8 | mahendranagar
# Processing Record 24 of Set 8 | mancio lima
# Processing Record 25 of Set 8 | saravan
# Processing Record 26 of Set 8 | calvinia
# Processing Record 27 of Set 8 | skibbereen
# Processing Record 28 of Set 8 | romny
# Processing Record 29 of Set 8 | shangzhi
# Processing Record 30 of Set 8 | graaff-reinet
# Processing Record 31 of Set 8 | saint anthony
# Processing Record 32 of Set 8 | zhigansk
# Processing Record 33 of Set 8 | thinadhoo
# Processing Record 34 of Set 8 | tilichiki
# Processing Record 35 of Set 8 | vysokogornyy
# Processing Record 36 of Set 8 | moyale
# Processing Record 37 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 8 | bambous virieux
# Processing Record 39 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 40 of Set 8 | poya
# Processing Record 41 of Set 8 | camapua
# Processing Record 42 of Set 8 | eregli
# Processing Record 43 of Set 8 | puerto colombia
# Processing Record 44 of Set 8 | keuruu
# Processing Record 45 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 8 | mayo
# Processing Record 47 of Set 8 | solnechnyy
# Processing Record 48 of Set 8 | pucallpa
# Processing Record 49 of Set 8 | sinnar
# Processing Record 50 of Set 8 | belmonte
# Processing Record 1 of Set 9 | beaupre
# Processing Record 2 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 9 | kavieng
# Processing Record 4 of Set 9 | kharan
# Processing Record 5 of Set 9 | macaubas
# Processing Record 6 of Set 9 | kabo
# Processing Record 7 of Set 9 | marsh harbour
# Processing Record 8 of Set 9 | kingman
# Processing Record 9 of Set 9 | tolaga bay
# Processing Record 10 of Set 9 | coxim
# Processing Record 11 of Set 9 | kloulklubed
# Processing Record 12 of Set 9 | travnik
# Processing Record 13 of Set 9 | vestmannaeyjar
# Processing Record 14 of Set 9 | egvekinot
# Processing Record 15 of Set 9 | panalingaan
# Processing Record 16 of Set 9 | iberia
# Processing Record 17 of Set 9 | envira
# Processing Record 18 of Set 9 | narsaq
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 9 | nome
# Processing Record 22 of Set 9 | male
# Processing Record 23 of Set 9 | semporna
# Processing Record 24 of Set 9 | ginda
# Processing Record 25 of Set 9 | lagoa
# Processing Record 26 of Set 9 | baykit
# Processing Record 27 of Set 9 | coro
# Processing Record 28 of Set 9 | camopi
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | boa vista
# Processing Record 31 of Set 9 | taltal
# Processing Record 32 of Set 9 | kenai
# Processing Record 33 of Set 9 | funtua
# Processing Record 34 of Set 9 | scunthorpe
# Processing Record 35 of Set 9 | padang
# Processing Record 36 of Set 9 | lucea
# Processing Record 37 of Set 9 | punto fijo
# Processing Record 38 of Set 9 | baiyin
# Processing Record 39 of Set 9 | praia da vitoria
# Processing Record 40 of Set 9 | mawlaik
# Processing Record 41 of Set 9 | bandarbeyla
# Processing Record 42 of Set 9 | chute-aux-outardes
# Processing Record 43 of Set 9 | kang
# Processing Record 44 of Set 9 | fort nelson
# Processing Record 45 of Set 9 | raga
# Processing Record 46 of Set 9 | pitimbu
# Processing Record 47 of Set 9 | vila franca do campo
# Processing Record 48 of Set 9 | port-gentil
# Processing Record 49 of Set 9 | lovozero
# Processing Record 50 of Set 9 | aljezur
# Processing Record 1 of Set 10 | harper
# Processing Record 2 of Set 10 | cracaoani
# City not found. Skipping...
# Processing Record 3 of Set 10 | tawau
# Processing Record 4 of Set 10 | roald
# Processing Record 5 of Set 10 | havelian
# Processing Record 6 of Set 10 | koumac
# Processing Record 7 of Set 10 | leopold
# Processing Record 8 of Set 10 | woodward
# Processing Record 9 of Set 10 | barabai
# Processing Record 10 of Set 10 | kaili
# Processing Record 11 of Set 10 | prince rupert
# Processing Record 12 of Set 10 | vila
# Processing Record 13 of Set 10 | nuevo progreso
# Processing Record 14 of Set 10 | linxia
# Processing Record 15 of Set 10 | eyl
# Processing Record 16 of Set 10 | ayagoz
# Processing Record 17 of Set 10 | akdepe
# Processing Record 18 of Set 10 | porto walter
# Processing Record 19 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 10 | ritchie
# Processing Record 21 of Set 10 | kashin
# Processing Record 22 of Set 10 | alice springs
# Processing Record 23 of Set 10 | magistralnyy
# Processing Record 24 of Set 10 | korhogo
# Processing Record 25 of Set 10 | byron bay
# Processing Record 26 of Set 10 | rodez
# Processing Record 27 of Set 10 | oriximina
# Processing Record 28 of Set 10 | simao
# Processing Record 29 of Set 10 | bilma
# Processing Record 30 of Set 10 | lima
# Processing Record 31 of Set 10 | surt
# Processing Record 32 of Set 10 | los llanos de aridane
# Processing Record 33 of Set 10 | high level
# Processing Record 34 of Set 10 | shenkursk
# Processing Record 35 of Set 10 | salalah
# Processing Record 36 of Set 10 | amapa
# Processing Record 37 of Set 10 | saint-denis
# Processing Record 38 of Set 10 | cockburn town
# Processing Record 39 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 10 | hay river
# Processing Record 41 of Set 10 | thunder bay
# Processing Record 42 of Set 10 | inuvik
# Processing Record 43 of Set 10 | valverde del camino
# Processing Record 44 of Set 10 | safford
# Processing Record 45 of Set 10 | pacifica
# Processing Record 46 of Set 10 | codrington
# Processing Record 47 of Set 10 | that phanom
# Processing Record 48 of Set 10 | odienne
# Processing Record 49 of Set 10 | aguimes
# Processing Record 50 of Set 10 | camacha
# Processing Record 1 of Set 11 | tabas
# Processing Record 2 of Set 11 | saint-louis
# Processing Record 3 of Set 11 | jizan
# Processing Record 4 of Set 11 | boda
# Processing Record 5 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 6 of Set 11 | kavaratti
# Processing Record 7 of Set 11 | dakar
# Processing Record 8 of Set 11 | tocopilla
# Processing Record 9 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 11 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 11 | lakeway
# Processing Record 13 of Set 11 | puerto narino
# Processing Record 14 of Set 11 | cabanas
# Processing Record 15 of Set 11 | ohara
# Processing Record 16 of Set 11 | armidale
# Processing Record 17 of Set 11 | dowa
# Processing Record 18 of Set 11 | beoumi
# Processing Record 19 of Set 11 | brokopondo
# Processing Record 20 of Set 11 | honolulu
# Processing Record 21 of Set 11 | mogapinyana
# Processing Record 22 of Set 11 | alcantara
# Processing Record 23 of Set 11 | port hedland
# Processing Record 24 of Set 11 | saint george
# Processing Record 25 of Set 11 | mporokoso
# Processing Record 26 of Set 11 | sitka
# Processing Record 27 of Set 11 | hearst
# Processing Record 28 of Set 11 | umm kaddadah
# Processing Record 29 of Set 11 | ormara
# Processing Record 30 of Set 11 | talcahuano
# Processing Record 31 of Set 11 | gat
# Processing Record 32 of Set 11 | amol
# Processing Record 33 of Set 11 | mount gambier
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | akyab
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | prescott
# Processing Record 38 of Set 11 | rosarito
# Processing Record 39 of Set 11 | ndola
# Processing Record 40 of Set 11 | aklavik
# Processing Record 41 of Set 11 | gombong
# Processing Record 42 of Set 11 | dawson creek
# Processing Record 43 of Set 11 | touros
# Processing Record 44 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | bintulu
# Processing Record 46 of Set 11 | diffa
# Processing Record 47 of Set 11 | udachnyy
# Processing Record 48 of Set 11 | berdigestyakh
# Processing Record 49 of Set 11 | prado
# Processing Record 50 of Set 11 | lufilufi
# Processing Record 1 of Set 12 | dali
# Processing Record 2 of Set 12 | ishigaki
# Processing Record 3 of Set 12 | kyra
# Processing Record 4 of Set 12 | balabac
# Processing Record 5 of Set 12 | promyshlennovskiy
# Processing Record 6 of Set 12 | tabuk
# Processing Record 7 of Set 12 | wanning
# Processing Record 8 of Set 12 | tucurui
# Processing Record 9 of Set 12 | hofn
# Processing Record 10 of Set 12 | atasu
# Processing Record 11 of Set 12 | zalaegerszeg
# Processing Record 12 of Set 12 | ribeira brava
# Processing Record 13 of Set 12 | laguna de perlas
# Processing Record 14 of Set 12 | la spezia
# Processing Record 15 of Set 12 | shimoda
# Processing Record 16 of Set 12 | dhidhdhoo
# Processing Record 17 of Set 12 | lata
# Processing Record 18 of Set 12 | lichinga
# Processing Record 19 of Set 12 | caravelas
# Processing Record 20 of Set 12 | sabang
# Processing Record 21 of Set 12 | csurgo
# Processing Record 22 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 12 | tombouctou
# Processing Record 24 of Set 12 | sigiriya
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | hervey bay
# Processing Record 27 of Set 12 | florianopolis
# Processing Record 28 of Set 12 | thurso
# Processing Record 29 of Set 12 | prestea
# Processing Record 30 of Set 12 | rypin
# Processing Record 31 of Set 12 | bathsheba
# Processing Record 32 of Set 12 | zeya
# Processing Record 33 of Set 12 | yumen
# Processing Record 34 of Set 12 | nishihara
# Processing Record 35 of Set 12 | mahanoro
# Processing Record 36 of Set 12 | magnitogorsk
# Processing Record 37 of Set 12 | gongzhuling
# Processing Record 38 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 12 | maun
# Processing Record 40 of Set 12 | tautira
# Processing Record 41 of Set 12 | pemangkat
# Processing Record 42 of Set 12 | shiyan
# Processing Record 43 of Set 12 | seydi
# Processing Record 44 of Set 12 | vallenar
# Processing Record 45 of Set 12 | camocim
# Processing Record 46 of Set 12 | jonkoping
# Processing Record 47 of Set 12 | candelaria
# Processing Record 48 of Set 12 | tazovskiy
# Processing Record 49 of Set 12 | khor
# Processing Record 50 of Set 12 | fauske
# Processing Record 1 of Set 13 | sur
# Processing Record 2 of Set 13 | olga
# Processing Record 3 of Set 13 | skowhegan
# Processing Record 4 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 13 | kushima
# Processing Record 6 of Set 13 | ouadda
# Processing Record 7 of Set 13 | kieta
# Processing Record 8 of Set 13 | makasar
# Processing Record 9 of Set 13 | qui nhon
# Processing Record 10 of Set 13 | rosario oeste
# Processing Record 11 of Set 13 | awjilah
# Processing Record 12 of Set 13 | kibaya
# Processing Record 13 of Set 13 | vila velha
# Processing Record 14 of Set 13 | windsor
# Processing Record 15 of Set 13 | shingu
# Processing Record 16 of Set 13 | oranjestad
# Processing Record 17 of Set 13 | antalaha
# Processing Record 18 of Set 13 | paita
# Processing Record 19 of Set 13 | grand gaube
# Processing Record 20 of Set 13 | damavand
# Processing Record 21 of Set 13 | sobolevo
# Processing Record 22 of Set 13 | pangoa
# Processing Record 23 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 13 | san quintin
# Processing Record 25 of Set 13 | deputatskiy
# Processing Record 26 of Set 13 | marzuq
# Processing Record 27 of Set 13 | san ignacio
# Processing Record 28 of Set 13 | imbituba
# Processing Record 29 of Set 13 | tayoltita
# Processing Record 30 of Set 13 | tambura
# Processing Record 31 of Set 13 | sola
# Processing Record 32 of Set 13 | altamont
# Processing Record 33 of Set 13 | beidao
# Processing Record 34 of Set 13 | sao joao da barra
# Processing Record 35 of Set 13 | drumheller
# Processing Record 36 of Set 13 | whitefish
# Processing Record 37 of Set 13 | ulaanbaatar
# Processing Record 38 of Set 13 | tukrah
# Processing Record 39 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 13 | biloela
# Processing Record 41 of Set 13 | bubaque
# Processing Record 42 of Set 13 | soma
# Processing Record 43 of Set 13 | uarini
# Processing Record 44 of Set 13 | matara
# Processing Record 45 of Set 13 | fonte boa
# Processing Record 46 of Set 13 | timiryazevskoye
# Processing Record 47 of Set 13 | raglan
# Processing Record 48 of Set 13 | mudgee
# Processing Record 49 of Set 13 | ostrovnoy
# Processing Record 50 of Set 13 | black river
# Processing Record 1 of Set 14 | andijon
# Processing Record 2 of Set 14 | walvis bay
# Processing Record 3 of Set 14 | mobara
# Processing Record 4 of Set 14 | shitanjing
# Processing Record 5 of Set 14 | eldorado
# Processing Record 6 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 14 | yerbogachen
# Processing Record 8 of Set 14 | phan thiet
# Processing Record 9 of Set 14 | raalte
# Processing Record 10 of Set 14 | chapais
# Processing Record 11 of Set 14 | gweta
# Processing Record 12 of Set 14 | aasiaat
# Processing Record 13 of Set 14 | atambua
# Processing Record 14 of Set 14 | svetlaya
# Processing Record 15 of Set 14 | codlea
# Processing Record 16 of Set 14 | bandeirantes
# Processing Record 17 of Set 14 | shenzhen
# Processing Record 18 of Set 14 | betare oya
# Processing Record 19 of Set 14 | shache
# Processing Record 20 of Set 14 | puerto suarez
# Processing Record 21 of Set 14 | westport
# Processing Record 22 of Set 14 | southbridge
# Processing Record 23 of Set 14 | naryan-mar
# Processing Record 24 of Set 14 | zhangjiakou
# Processing Record 25 of Set 14 | eidsvag
# Processing Record 26 of Set 14 | ust-koksa
# Processing Record 27 of Set 14 | cururupu
# Processing Record 28 of Set 14 | tahe
# Processing Record 29 of Set 14 | lingao
# Processing Record 30 of Set 14 | iquitos
# Processing Record 31 of Set 14 | general pico
# Processing Record 32 of Set 14 | copiapo
# Processing Record 33 of Set 14 | rolla
# Processing Record 34 of Set 14 | luebo
# Processing Record 35 of Set 14 | abnub
# Processing Record 36 of Set 14 | papillion
# Processing Record 37 of Set 14 | huarmey
# Processing Record 38 of Set 14 | tirumullaivasal
# Processing Record 39 of Set 14 | melfort
# Processing Record 40 of Set 14 | msowero
# Processing Record 41 of Set 14 | santa isabel do rio negro
# Processing Record 42 of Set 14 | abomey
# Processing Record 43 of Set 14 | plettenberg bay
# Processing Record 44 of Set 14 | luanda
# Processing Record 45 of Set 14 | umm lajj
# Processing Record 46 of Set 14 | orlik
# Processing Record 47 of Set 14 | iwanai
# Processing Record 48 of Set 14 | morwell
# Processing Record 49 of Set 14 | jafarpur
# Processing Record 50 of Set 14 | marsa matruh
# Processing Record 1 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 15 | laredo
# Processing Record 3 of Set 15 | morehead
# Processing Record 4 of Set 15 | katobu
# Processing Record 5 of Set 15 | pichayevo
# Processing Record 6 of Set 15 | xinxiang
# Processing Record 7 of Set 15 | sabaudia
# Processing Record 8 of Set 15 | shenjiamen
# Processing Record 9 of Set 15 | rabo de peixe
# Processing Record 10 of Set 15 | sitges
# Processing Record 11 of Set 15 | souillac
# Processing Record 12 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 15 | vaitape
# Processing Record 14 of Set 15 | pasca
# Processing Record 15 of Set 15 | baijiantan
# Processing Record 16 of Set 15 | ramsi
# Processing Record 17 of Set 15 | marang
# Processing Record 18 of Set 15 | ucluelet
# Processing Record 19 of Set 15 | dolzhanskaya
# Processing Record 20 of Set 15 | seguela
# Processing Record 21 of Set 15 | san ramon de la nueva oran
# Processing Record 22 of Set 15 | novomykolayivka
# Processing Record 23 of Set 15 | bonavista
# Processing Record 24 of Set 15 | manokwari
# Processing Record 25 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 27 of Set 15 | grants
# Processing Record 28 of Set 15 | gua musang
# Processing Record 29 of Set 15 | otradnoye
# Processing Record 30 of Set 15 | teknaf
# Processing Record 31 of Set 15 | mazarron
# Processing Record 32 of Set 15 | tondano
# Processing Record 33 of Set 15 | nouadhibou
# Processing Record 34 of Set 15 | matagami
# Processing Record 35 of Set 15 | freeport
# Processing Record 36 of Set 15 | jackson
# Processing Record 37 of Set 15 | san rafael
# Processing Record 38 of Set 15 | campbell river
# Processing Record 39 of Set 15 | stony plain
# Processing Record 40 of Set 15 | north bend
# Processing Record 41 of Set 15 | mayumba
# Processing Record 42 of Set 15 | mwinilunga
# Processing Record 43 of Set 15 | north platte
# Processing Record 44 of Set 15 | tabou
# Processing Record 45 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 15 | nytva
# Processing Record 47 of Set 15 | elizabeth city
# Processing Record 48 of Set 15 | gallipoli
# Processing Record 49 of Set 15 | porto santo
# Processing Record 50 of Set 15 | limbang
# Processing Record 1 of Set 16 | durban
# Processing Record 2 of Set 16 | nikki
# Processing Record 3 of Set 16 | riohacha
# Processing Record 4 of Set 16 | usinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura -46.1927  168.8643     45.48        92          94
# 1    Bredasdorp -34.5322   20.0403     80.87        24          21
# 2          Roma  43.2128  -75.4557     52.95        94          98
# 3      Karratha -20.7377  116.8463     72.59        89          99
# 4     Carnarvon -24.8667  113.6333     72.30        61           0
# ..          ...      ...       ...       ...       ...         ...
# 690     Limbang   4.7500  115.0000     77.11        97         100
# 691      Durban -29.8579   31.0292     78.93        81           0
# 692       Nikki   9.9401    3.2108     99.14        28          26
# 693    Riohacha  11.5444  -72.9072     82.51        83          75
# 694      Usinsk  65.9939   57.5281     38.91        72         100
#
#      Wind Speed Country                 Date Current Description
# 0          3.15      NZ  2022-05-17 13:05:06     overcast clouds
# 1          6.93      ZA  2022-05-17 13:05:07          few clouds
# 2          4.00      US  2022-05-17 12:54:03     overcast clouds
# 3          5.73      AU  2022-05-17 13:05:07          light rain
# 4          8.46      AU  2022-05-17 13:05:08           clear sky
# ..          ...     ...                  ...                 ...
# 690        2.71      MY  2022-05-17 13:23:17     overcast clouds
# 691        4.00      ZA  2022-05-17 13:24:17           clear sky
# 692        4.32      BJ  2022-05-17 13:24:18    scattered clouds
# 693        9.22      CO  2022-05-17 13:24:18       broken clouds
# 694       13.27      RU  2022-05-17 13:24:18     overcast clouds
#
# [695 rows x 10 columns]

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0     Mataura      NZ  2022-05-17 13:05:06 -46.1927  168.8643     45.48
# 1  Bredasdorp      ZA  2022-05-17 13:05:07 -34.5322   20.0403     80.87
# 2        Roma      US  2022-05-17 12:54:03  43.2128  -75.4557     52.95
# 3    Karratha      AU  2022-05-17 13:05:07 -20.7377  116.8463     72.59
# 4   Carnarvon      AU  2022-05-17 13:05:08 -24.8667  113.6333     72.30
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        92          94        3.15     overcast clouds
# 1        24          21        6.93          few clouds
# 2        94          98        4.00     overcast clouds
# 3        89          99        5.73          light rain
# 4        61           0        8.46           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
